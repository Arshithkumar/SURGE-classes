# %%
import pandas as pd
df = pd.DataFrame([[1, 2.12], [3.356, 4.567]])
df
# Out:
#        0      1
# 0  1.000  2.120
# 1  3.356  4.567

# %%
df.applymap(lambda x: len(str(x)))
# Out:
#    0  1
# 0  3  4
# 1  5  5

# %%
u
