# %% [markdown]
# # <u>Python - Tuples :

# %%
type([1,2,3,4])

# %%
type('surge')

# %%
type((1,2,3,4))

# %%
type({1,2,3,4})

# %%
Dict

Key: Value pair

# %%
NonIterable datatypes

int float

Iterable datatypes
list,tuple,set,dict,str

# %%
[1,2,3,4,5] list mutable

(1,2,3,4,5) tuple immutable

# %% [markdown]
# Creating a tuple is as simple as putting different comma-separated values. Optionally you can put these comma-separated values between parentheses

# %%
tup1 = ('Machine Learning', 'VLSI', 2017, 2020)
tup2 = (1, 2, 3, 4, 5 )
tup3 = ("a", "b", "c", "d")

# %%
print(tup1)

# %%
print(tup2)

# %%
print(tup3)

# %% [markdown]
# The empty tuple is written as two parentheses containing nothing

# %%
tup1 = ()

# %% [markdown]
# To write a tuple containing a single value you have to include a comma, even though there is only one value

# %%
tup1 = (50,)

print(tup1)

# %%
type(tup1)

# %%
tup2=(50)

print(tup2)

# %%
type(tup2)

# %% [markdown]
# ### Accessing Values in Tuples<br>
# To access values in tuple, use the square brackets for slicing along with the index or indices to obtain value available at that index

# %%
tup1 = ('machine learning', 'vlsi', 2017, 2020);

print ("tup1[0]: ", tup1[0])

# %%
tup2 = (1, 2, 3, 4, 5, 6, 7 );

print ("tup2[1:5]: ", tup2[1:5])

# %% [markdown]
# ## Updating Tuples<br>
# Tuples are immutable which means you cannot update or change the values of tuple elements.

# %%
tup1 = (12, 34.56);
tup2 = ('abc', 'xyz');

# Following action is not valid for tuples
tup1[0] = 100;
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16504/3126588203.py in <module>
#       3
#       4 # Following action is not valid for tuples
# ----> 5 tup1[0] = 100;
#       6
#
# TypeError: 'tuple' object does not support item assignment

# %%
# So let's create a new tuple as follows
tup3 = tup1 + tup2
print (tup3)
# Out:
# (12, 34.56, 'abc', 'xyz')

# %% [markdown]
# ### Delete Tuple Elements<br>
# Removing individual tuple elements is not possible.

# %%
tup = ('machine learning', 'vlsi', 2017, 2020);
print (tup)
# Out:
# ('machine learning', 'vlsi', 2017, 2020)

# %%
del(tup)
print ("After deleting tup : ")
print(tup)
#Will get error as the tuple doesnt exists anymore
# Out:
# After deleting tup :
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16504/1117940728.py in <module>
#       1 del(tup)
#       2 print ("After deleting tup : ")
# ----> 3 print(tup)
#       4 #Will get error as the tuple doesnt exists anymore
#
# NameError: name 'tup' is not defined

# %% [markdown]
# ## Built-in Tuple Functions

# %% [markdown]
# len(tuple)->Gives the total length of the tuple.<br>
#
# max(tuple)->Returns item from the tuple with max value.<br>
#
# min(tuple)->Returns item from the tuple with min value.<br>
#
# tuple(seq)->Converts a list into tuple<br>

# %%
tuple1, tuple2 = (123, 'surge', 'classes'), (456, 'machines')
#len of tuple
print("First tuple length : ", len(tuple1))
print ("Second tuple length : ", len(tuple2))
# Out:
# First tuple length :  3
# Second tuple length :  2

# %%
#min and max of tuple
tuple3=(1,2,3,4,5)
print ("Max tuple  : ", max(tuple3))
print ("min tuple  : ", min(tuple3))
# Out:
# Max tuple  :  5
# min tuple  :  1

# %%
#Convert list to tuple
list1=[1,2,3,4]
print("List to tuple :",tuple(list1) )
# Out:
# List to tuple : (1, 2, 3, 4)

# %%
import pandas as pd
tup_df=pd.DataFrame({'names':['x','y','z'],'no':[1,2,3]})

# %%
tup_df
# Out:
#   names  no
# 0     x   1
# 1     y   2
# 2     z   3

# %%
tup_df.shape
# Out:
# (3, 2)

# %%
type(tup_df.shape)
# Out:
# tuple

# %%
tup_df.shape[1]
# Out:
# 2

# %%
tup_df.shape[0]
# Out:
# 3

# %% [markdown]
# # <u> Python - Sets :

# %% [markdown]
# ### The sets in python are typically used for mathematical operations like union, intersection, difference and complement etc. We can create a set, access it’s elements and carry out these mathematical operations

# %% [markdown]
# ## Creating a set
#
# A set is created by using the set() function or placing all the elements within a pair of curly braces

# %%
Days=set(["Mon","Tue","Wed","Thu","Fri","Sat","Sun"])
Months={"Jan","Feb","Mar"}
Dates={21,22,17}
print(Days)
print(Months)
print(Dates)
# Out:
# {'Tue', 'Sat', 'Mon', 'Fri', 'Wed', 'Sun', 'Thu'}
# {'Feb', 'Mar', 'Jan'}
# {17, 21, 22}

# %%
set_1={1,2,2,3,3,3,4}

set_1
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# ### Accessing Values in a Set
# We cannot access individual values in a set. We can only access all the elements together as shown above. But we can also get a list of individual elements by looping through the set.

# %%
Days=set(["Mon","Tue","Wed","Thu","Fri","Sat","Sun"])

# %%
Days
# Out:
# {'Fri', 'Mon', 'Sat', 'Sun', 'Thu', 'Tue', 'Wed'}

# %%
Days[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16504/3986967366.py in <module>
# ----> 1 Days[3]
#
# TypeError: 'set' object is not subscriptable

# %%
Days
# Out:
# {'Fri', 'Mon', 'Sat', 'Sun', 'Thu', 'Tue', 'Wed'}

# %%
for d in Days:
    print(d)
# Out:
# Tue
# Sat
# Mon
# Fri
# Wed
# Sun
# Thu

# %% [markdown]
# ### Adding Items to a Set
# We can add elements to a set by using add() method.

# %%
Days=set(["Mon","Tue","Wed","Thu","Fri","Sat"])
 
print(Days)
# Out:
# {'Tue', 'Sat', 'Mon', 'Fri', 'Wed', 'Thu'}

# %%
Days.add("Sun")
print(Days)
# Out:
# {'Tue', 'Sat', 'Mon', 'Fri', 'Wed', 'Sun', 'Thu'}

# %%
Days.add('Zero Day')

# %%
Days
# Out:
# {'Fri', 'Mon', 'Sat', 'Sun', 'Thu', 'Tue', 'Wed', 'Zero Day'}

# %% [markdown]
# ### Removing Item from a Set
# We can remove elements from a set by using discard() method. Again as discussed there is no specific index attached to the newly added element.

# %%
Days=set(["Mon","Tue","Wed","Thu","Fri","Sat"])
print('Printing before')
print(Days)
Days.discard("Mon")
print('Printing after')
print(Days)
# Out:
# Printing before
# {'Tue', 'Sat', 'Mon', 'Fri', 'Wed', 'Thu'}
# Printing after
# {'Tue', 'Sat', 'Fri', 'Wed', 'Thu'}

# %% [markdown]
# ### Union of Sets
# The union operation on two sets produces a new set containing all the distinct elements from both the sets. In the below example the element “Wed” is present in both the sets.

# %%
DaysA = set(["Mon","Tue","Wed"])
DaysB = set(["Wed","Thu","Fri","Sat","Sun"])
AllDays = DaysA|DaysB
print(AllDays)
# Out:
# {'Tue', 'Sat', 'Mon', 'Wed', 'Fri', 'Sun', 'Thu'}

# %% [markdown]
# ### Intersection of Sets
# The intersection operation on two sets produces a new set containing only the common elements from both the sets. In the below example the element “Wed” is present in both the sets.

# %%
DaysA = set(["Mon","Tue","Wed"])
DaysB = set(["Wed","Thu","Fri","Sat","Sun"])
AllDays = DaysA & DaysB
print(AllDays)
# Out:
# {'Wed'}

# %% [markdown]
# ### Difference of Sets
# The difference operation on two sets produces a new set containing only the elements from the first set and none from the second set. In the below example the element “Wed” is present in both the sets so it will not be found in the result set.

# %%
DaysA = set(["Mon","Tue","Wed"])
DaysB = set(["Wed","Thu","Fri","Sat","Sun"])
AllDays = DaysA - DaysB
print(AllDays)
# Out:
# {'Tue', 'Mon'}

# %% [markdown]
# ### Compare Sets
# We can check if a given set is a subset or superset of another set. The result is True or False depending on the elements present in the sets.

# %%
DaysA = set(["Mon","Tue","Wed"])
DaysB = set(["Mon","Tue","Wed","Thu","Fri","Sat","Sun"])
SubsetRes = DaysA <= DaysB
SupersetRes = DaysB >= DaysA
print(SubsetRes)
print(SupersetRes)
# Out:
# True
# True

# %%
Knowledge Discovery and Interoperability

# %%
Machine Communication

knowledge discovery

interoperability


XML

user defined tags....

<tag>value</tag>

GML
attribute.... value

SML

{'cus_id':123,'payment':'error'}

# %%
Student_dict={'Student_name': 'Jashank',
'Location': 'Hyd',
'Marks': 91}
    

#Key: Value
    
#JSON

# %%
type(Student_dict)
# Out:
# dict

# %%
Student_dict
# Out:
# {'Student_name': 'Jashank', 'Location': 'Hyd', 'Marks': 91}

# %%
for i in Student_dict:
    print(i)
    
#keys
# Out:
# Student_name
# Location
# Marks

# %%
for i in Student_dict.items():
    print(i)
    
#keys

each item is a key value pair... they are in the form of Tuple
# Out:
# ('Student_name', 'Jashank')
# ('Location', 'Hyd')
# ('Marks', 91)

# %%
for i in Student_dict.items():
    print(i[0])
# Out:
# Student_name
# Location
# Marks

# %%
for i in Student_dict.items():
    print(i[1])
# Out:
# Jashank
# Hyd
# 91

# %%
Student_dict.keys()
# Out:
# dict_keys(['Student_name', 'Location', 'Marks'])

# %%
list(Student_dict.keys())
# Out:
# ['Student_name', 'Location', 'Marks']

# %%
Student_dict.values()
# Out:
# dict_values(['Jashank', 'Hyd', 91])

# %%
list(Student_dict.values())
# Out:
# ['Jashank', 'Hyd', 91]

# %%
Student_dict['Student_name']
# Out:
# 'Jashank'

# %%
{'Name':'Vishwa','Roll':'SCDS00203','Marks':86}

keys: 'Name','Roll','Marks'
values: 'Vishwa','SCDS00203',86

# %%
#
json _format

key value pair

{'keys':values}

{'key_1':value_1,
'key_2':value_2}

{'key_1':value_1,'key_2':value_2}

{item_1,item_2}


Dictionary

2500 variables

names has been changed

old_names

corresponding

new_names


new_names... list
old_names.... another list


mapping_dict

{'old_name':new_name}


replaced_strategy..... mapping_dict....

# %% [markdown]
# # <u>Python - Dictionary:

# %% [markdown]
# Each key is separated from its value by a colon (:), the items are separated by commas, and the whole thing is enclosed in curly braces. An empty dictionary without any items is written with just two curly braces, like this: {}

# %% [markdown]
# ### Accessing Values in Dictionary
# To access dictionary elements, you can use the familiar square brackets along with the key to obtain its value. Following is a simple example

# %%
dict_1 = {'Name': 'surge classes', 'Age': 1, 'Class': 'R&D'}

# %%
dict_1
# Out:
# {'Name': 'surge classes', 'Age': 1, 'Class': 'R&D'}

# %%
dict_1['Age']
# Out:
# 1

# %%
dict_1['Class']
# Out:
# 'R&D'

# %%
print ("dict_1['Name']: ", dict_1['Name'])
print ("dict_1['Age']: ", dict_1['Age'])
# Out:
# dict_1['Name']:  surge classes
# dict_1['Age']:  1

# %%
type(('Name', 'surge classes'))
# Out:
# tuple

# %%
dict_1.keys()
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
dict_1.values()
# Out:
# dict_values(['surge classes', 1, 'R&D'])

# %%
print(list(dict_1.values()))
# Out:
# ['surge classes', 1, 'R&D']

# %%
dict_1.items()
# Out:
# dict_items([('Name', 'surge classes'), ('Age', 1), ('Class', 'R&D')])

# %%
for var in dict_1.items():
    print(var)
# Out:
# ('Name', 'surge classes')
# ('Age', 1)
# ('Class', 'R&D')

# %%
dict_1['Class']
# Out:
# 'R&D'

# %%
for var in dict_1.items():
    print(var)
    print(var[0])
# Out:
# ('Name', 'surge classes')
# Name
# ('Age', 1)
# Age
# ('Class', 'R&D')
# Class

# %%
for var in dict_1.items():
    print(var)
    print(var[0])

# %%
for var in dict_1.items():
    print(var)
    if var[0]=='Class':
        print(var[1])
# Out:
# ('Name', 'surge classes')
# ('Age', 1)
# ('Class', 'R&D')
# R&D

# %%
# Output: ['English', 'Math', 'Science']
print(list(sorted(dict_1.keys())))
# Out:
# ['Age', 'Class', 'Name']

# %%
"""
company_1=['surge classes',1,'R&D']
company_2=['upgrad',6,'edtech']

# %% [markdown]
# ### Updating Dictionary
# You can update a dictionary by adding a new entry or a key-value pair, modifying an existing entry, or deleting an existing entry as shown below in the simple example −

# %%
dict = {'Name': 'surge', 'Age': 1, 'Class': 'R&D'}

print(dict)
# Out:
# {'Name': 'surge', 'Age': 1, 'Class': 'R&D'}

# %%
dict['Age'] = 8; # update existing entry

# %%
print(dict)
# Out:
# {'Name': 'surge', 'Age': 8, 'Class': 'R&D'}

# %%
dict['location'] = "Bangalore"; # Add new entry

# %%
print(dict)
# Out:
# {'Name': 'surge', 'Age': 8, 'Class': 'R&D', 'location': 'Bangalore'}

# %%
print ("dict['Age']: ", dict['Age'])
print ("dict['location']: ", dict['location'])
# Out:
# dict['Age']:  8
# dict['location']:  Bangalore

# %% [markdown]
# ### Delete Dictionary Elements
# You can either remove individual dictionary elements or clear the entire contents of a dictionary. You can also delete entire dictionary in a single operation.
#
# To explicitly remove an entire dictionary, just use the del statement

# %%
dict = {'Name': 'surge', 'Age': 1, 'Class': 'R&D'}

# %%
dict
# Out:
# {'Name': 'surge', 'Age': 1, 'Class': 'R&D'}

# %%
del dict['Name']; # remove entry with key 'Name'

# %%
dict
# Out:
# {'Age': 1, 'Class': 'R&D'}

# %%
dict.clear();     # remove all entries in dict

# %%
dict
# Out:
# {}

# %%
dict_1={'doubt':'looping','count':4}

# %%
del dict_1 ;     # delete entire dictionary

# %%
dict_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16504/1976856482.py in <module>
# ----> 1 dict_1
#
# NameError: name 'dict_1' is not defined

# %% [markdown]
# ### Properties of Dictionary Keys

# %% [markdown]
# More than one entry per key not allowed. Which means no duplicate key is allowed. When duplicate keys encountered during assignment, the last assignment wins.

# %%
dict = {'Name': 'surge classes', 'Age': 1, 'Name': 'jalla labs pvt. ltd.'}

print(dict)
print ("dict['Name']: ", dict['Name'])
# Out:
# {'Name': 'jalla labs pvt. ltd.', 'Age': 1}
# dict['Name']:  jalla labs pvt. ltd.

# %% [markdown]
# Keys must be immutable. Which means you can use strings, numbers or tuples as dictionary keys but something like ['key'] is not allowed. Following is a simple example −

# %%
dict = {['Name']: 'Zara', 'Age': 7}
print("dict['Name']: ", dict['Name'])
#the following gives an error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16504/2293094190.py in <module>
# ----> 1 dict = {['Name']: 'Zara', 'Age': 7}
#       2 print("dict['Name']: ", dict['Name'])
#       3 #the following gives an error
#
# TypeError: unhashable type: 'list'

# %%
dict = {'Name': 'Zara', 'Age': 7}
print("dict['Name']: ", dict['Name'])
#the following gives an error
# Out:
# dict['Name']:  Zara

# %%
my_dict={'Students':['Reshma','Namitha','Shristi','Mahesh','Ravi','Yeshwant','Vishwa','Vijay','Krishna'],'Roll':[1,2,3,4,5,6,7,8,9]}

# %%
my_dict
# Out:
# {'Students': ['Reshma',
#   'Namitha',
#   'Shristi',
#   'Mahesh',
#   'Ravi',
#   'Yeshwant',
#   'Vishwa',
#   'Vijay',
#   'Krishna'],
#  'Roll': [1, 2, 3, 4, 5, 6, 7, 8, 9]}

# %%
my_dict={1:['Reshma','Namitha','Shristi','Mahesh','Ravi','Yeshwant','Vishwa','Vijay','Krishna'],2:[1,2,3,4,5,6,7,8,9]}

# %%
my_dict
# Out:
# {1: ['Reshma',
#   'Namitha',
#   'Shristi',
#   'Mahesh',
#   'Ravi',
#   'Yeshwant',
#   'Vishwa',
#   'Vijay',
#   'Krishna'],
#  2: [1, 2, 3, 4, 5, 6, 7, 8, 9]}

# %%
import pandas as pd

my_df=pd.DataFrame(my_dict)

# %%
my_df.head(9)
# Out:
#           1  2
# 0    Reshma  1
# 1   Namitha  2
# 2   Shristi  3
# 3    Mahesh  4
# 4      Ravi  5
# 5  Yeshwant  6
# 6    Vishwa  7
# 7     Vijay  8
# 8   Krishna  9

# %%
# empty dictionary
my_dict = {}

# dictionary with integer keys
my_dict = {1: 'apple', 2: 'ball'}

# %%
# dictionary with mixed keys
my_dict = {'name': 'John', 1: [2, 4, 3]}

# %%
If we use the square brackets [], KeyError is raised in case a key is not found in the dictionary. 
On the other hand, the get() method returns None if the key is not found.

# %%
# get vs [] for retrieving elements
my_dict = {'name': 'Jack', 'age': 26}

# Output: Jack
print(my_dict['name'])
# Out:
# Jack

# %%
my_dict
# Out:
# {'name': 'Jack', 'age': 26}

# %%
my_dict['name']
# Out:
# 'Jack'

# %%
# Output: 26
print(my_dict.get('age'))
# Out:
# 26

# %%
# Trying to access keys which doesn't exist throws error
# Output None
print(my_dict.get('address'))
# Out:
# None

# %%
# KeyError
print(my_dict['address'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16504/4255559253.py in <module>
#       1 # KeyError
# ----> 2 print(my_dict['address'])
#
# KeyError: 'address'

# %%
"""
We can remove a particular item in a dictionary by using the pop() method. 

This method removes an item with the provided key and returns the value.

The popitem() method can be used to remove and return an arbitrary (key, value) item pair from the dictionary.

# %%
# Removing elements from a dictionary

# create a dictionary
squares = {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# remove a particular item, returns its value
# Output: 16
print(squares.pop(4))
# Out:
# 16

# %%
# Output: {1: 1, 2: 4, 3: 9, 5: 25}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 5: 25}

# %%
# remove an arbitrary item, return (key,value)
# Output: (5, 25)
print(squares.popitem())

# Output: {1: 1, 2: 4, 3: 9}
print(squares)
# Out:
# (5, 25)
# {1: 1, 2: 4, 3: 9}

# %%
# remove all items
squares.clear()

# Output: {}
print(squares)

# delete the dictionary itself
del squares

# Throws Error
print(squares)

# %%
# Dictionary Methods
marks = {}.fromkeys(['Math', 'English', 'Science'], 0)

# Output: {'English': 0, 'Math': 0, 'Science': 0}
print(marks)
# Out:
# {'Math': 0, 'English': 0, 'Science': 0}

# %%
for item in marks.items():
    print(item)
    
# Output: ['English', 'Math', 'Science']
print(list(sorted(marks.keys())))

print(list(marks.values()))
# Out:
# ('Math', 0)
# ('English', 0)
# ('Science', 0)
# ['English', 'Math', 'Science']
# [0, 0, 0]

# %%
We can iterate through each key in a dictionary using a for loop

# %%
# Iterating through a Dictionary
squares = {1: 1, 3: 9, 5: 25, 7: 49, 9: 81}
for i in squares:
    print(squares[i])
# Out:
# 1
# 9
# 25
# 49
# 81
