# %%
Datatypes
Operators
Lists
Strings

# %%
comparison operator: True/False
Arthmetic operator: Num values
Membership Operator:True/False
    
conditions

# %%
num=21
num%2 == 0 #even or odd condition
# Out:
# False

# %%
if else

condtion

condition is True: If Statement will be executed
condition is False: Else statement will be executed

# %%
num=27
if num%2 == 0:
    print('number is even')
else:
    print('number is odd')
# Out:
# number is odd

# %%
num=28
if num%2 == 0:
    print('number is even')
else:
    print('number is odd')
# Out:
# number is even

# %%
#printing outputs, variables

#creating a variable
num=10
#printing the variable
print(num)
# Out:
# 10

# %%
#printing the string
print('My name is Krishna')
#printing the string and variable
# Out:
# My name is Krishna

# %%
number=9167797971
print('My no. is:',number)
# Out:
# My no. is: 9167797971

# %%
college='CMRIT'

print('my college is:',college)
# Out:
# my college is: CMRIT

# %%
name='Surge Classes'
print('My name is {}'.format(name))
# Out:
# My name is Surge Classes

# %%
name='Jalla Labs'
print('My name is {}'.format(name))
# Out:
# My name is Jalla Labs

# %%
"Krishna is my name"

# %%
name='Krishna'

print('{} is my Name'.format(name))
# Out:
# Krishna is my Name

# %%
name='Krishna'
print('{} is my name'.format(name))
# Out:
# Krishna is my name

# %%
#simple case

given a string:'the location of Vishwa is Bangalore'

incase, string has Vishwa, output has to be  'This is the location statement of Vishwa'
incase, string has no Vishwa, output has to be 'This is statement of someone else'

# %%
"""
given a number
if number is even... print 'it is even'
if number is odd... print 'it is odd'

# %%
#identify the condition
num #number
condition: num%2==0

# %%
num=101
if num%2==0:
    print('even')#if statements #will be executed when condition is true
else:
    print('not even')
# Out:
# not even

# %%
num=1000
if num%2==0:
    print('even')#if statements #will be executed when condition is true
else:
    print('not even')
# Out:
# even

# %%
if condition:
    condition true statements
else:
    false statements

# %%
num=22

# %%
if num%2==0:
    true statements
else:
    false statements

# %%
if number is even..condition is true. print 'it is even'
if number is odd...condition is false  print 'it is odd'

# %%
num=2017

# %%
if num%2==0:
    #when condition is true, this print statement will be executed
    print('it is even')
else:
    #when condition is false, this print statement will be executed
    print('it is odd')

# %%
var=12

# %%
if var%2==0:
    print('yes, it is even')
else:
    print('No.')
# Out:
# yes, it is even

# %%
num=12
if num%2==0:
    #when condition is true, this print statement will be executed
    print('it is even')
else:
    #when condition is false, this print statement will be executed
    print('it is odd')

# %%
given a character
if charcter is vowel... print 'it is vowel'
if character is consonant... print 'it is consonant'

# %%
char #character
condition: char in 'aeiou'

# %%
char='i'
char in 'aeiou'
# Out:
# True

# %%
char='s'
char in 'aeiou'
# Out:
# False

# %%
condition: True or False
    
comparision or membership operators

# %%
char='m'
if char in 'aeiou':
    print('it is vowel')
else:
    print('it is consonant')
# Out:
# it is consonant

# %%
char='a'
if char in 'aeiou':
    print('it is vowel')
else:
    print('it is consonant')
# Out:
# it is vowel

# %%
char='m'
if char in ['a','e','i','o','u']:
    print('it is vowel')
else:
    print('it is consonant')

# %%
"""
given a string:'the location of Vishwa is Bangalore'

if string has Vishwa, print 'This is the location statement of Vishwa'
if string has no Vishwa, print 'This is statement of someone else'

# %%
my_string='the location of Vishwa is Bangalore'

print(my_string.find('Rahul'))
# Out:
# -1

# %%
location_string='the location of Vishwa is Bangalore'
if location_string.find('Vishwa') != -1:
    print('This is the location statement of Vishwa')
else:
    print('This is statement of someone else')
# Out:
# This is the location statement of Vishwa

# %%
my_string='the location of Vishwa is Bangalore'

print(my_string.find('Vishwa'))
# Out:
# 16

# %%
my_string.find('Vishwa')!=-1

# %%
my_string='the location of Yeshwant is Kadiri'

print(my_string.find('Vishwa'))

#my_string.find('Vishwa')!=-1
# Out:
# -1

# %%
location_statement_string='the location of Vishwa is Bangalore'

if location_statement_string.find('Vishwa') !=-1:
    print('This is the location statement of Vishwa')
else:
    print('This is location statement of someone else')
# Out:
# This is the location statement of Vishwa

# %%
location_statement_string='the location of Yeshwant is Kadiri'

if location_statement_string.find('Vishwa') !=-1:
    print('This is the location statement of Vishwa')
else:
    print('This is statement of someone else')
# Out:
# This is statement of someone else

# %%
location_statement_string='the location of Vishwa is Bangalore'
student_name='Vishwa'
if location_statement_string.find(student_name) !=-1:
    print('This is the location statement of {}'.format(student_name))
else:
    print('This is statement of someone else')
# Out:
# This is the location statement of Vishwa

# %%
location_statement_string='the location of Yeshwant is Kadiri'
student_name='Yeshwant'
if location_statement_string.find(student_name) !=-1:
    print('This is the location statement of {}'.format(student_name))
else:
    print('This is statement of someone else')
# Out:
# This is the location statement of Yeshwant

# %%
location_statement_string='the location of Yeshwant is Kadiri'
student_name='Vijay'
if location_statement_string.find(student_name) !=-1:
    print('This is the location statement of {}'.format(student_name))
else:
    print('This is not the statement of {}'.format(student_name))
# Out:
# This is not the statement of Vijay

# %%
location_statement_string='the location of Yeshwant is Kadiri'
student_name='Vijay'
if location_statement_string.find(student_name) !=-1:
    print('This is the location statement of {}'.format(student_name))
else:
    print('This is not the statement of {}'.format(student_name))
# Out:
# This is not the statement of Vijay

# %%
given a two numbers
if num1 is greater than num2... 'num1 is greater'
if num1 is lesser  than num2... 'num1 is lesser'

# %%
condition: num1>num2

# %%
num1=100
num2=120

if num1>num2:
    print("num1 is greater")
else:
    print("num1 is lesser")
# Out:
# num1 is lesser

# %%
num1=100
num2=120

100>120 False

num1=1000
num2=120

1000>120 True

num1=100
num2=100

# %%
num1=100
num2=100

if num1>num2:
    print("num1 is greater")
else:
    print("num1 is lesser")
# Out:
# num1 is lesser

# %%
#this is wrong statement

# %%
if
elif
else

# %%
num1=100
num2=120 

if num1>num2:
    print("num1 is greater")
elif num1<num2:
    print("num1 is lesser")
else:
    print("Both are equal")
# Out:
# num1 is lesser

# %%
   
num1=100
num2=100 

if num1>num2:#False
    print("num1 is greater")
elif num1<num2:#False
    print("num1 is lesser")
else:
    print("Both are equal")
# Out:
# Both are equal

# %%
   
num1=1000
num2=120 

if num1>num2:
    print("num1 is greater")
elif num1<num2:
    print("num1 is lesser")
else:
    print("Both are equal")
# Out:
# num1 is greater

# %%
given 

marks_obtained
Passing_cutt_off
attendance

if marks_obtained greater than passing cut_off also attendance minimum of 75 print('passed')

if marks_obtained equal to passing cut_off also attendance minimum of 75 print(' just passed')

if marks_obtained greater than passing cut_off also attendance lesser than 75 print('passed but inform parents')

if marks_obtained lesser than passing cut_off  print('failed')

# %%
marks_obtained> Passing_cutt_off
attendance>75

full_condition..... condition_1 condition_2

# %%
marks_obtained=41
Passing_cutt_off=62
attendance=81

# %%
if marks_obtained> Passing_cutt_off and attendance>75:#41>62 F ....F
    print("passed")
    
elif marks_obtained== Passing_cutt_off and attendance>75:# 41==62  F.....F
    print('Just passed')
    
elif marks_obtained> Passing_cutt_off and attendance<75:#41>62 F ....F
    print('passed but inform parents')
        
else:
    print('Failed')
# Out:
# Failed
