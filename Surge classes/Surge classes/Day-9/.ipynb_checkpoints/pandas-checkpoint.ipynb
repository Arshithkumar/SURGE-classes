# %%
import pandas as pd
import numpy as np

data = np.random.rand(5, 3) 
df = pd.DataFrame(data, columns=['Column1', 'Column2', 'Column3'])

print(df)
# Out:
#     Column1   Column2   Column3
# 0  0.425013  0.763069  0.491996
# 1  0.166322  0.173904  0.736453
# 2  0.662530  0.499334  0.648136
# 3  0.404235  0.895022  0.677993
# 4  0.344651  0.038914  0.915386

# %%
import pandas as pd
data = {'col 1':['surge','classes','AI','DS'],'col 2':[20,21,19,18]}
df=pd.DataFrame(data)
print(df)
# Out:
#      col 1  col 2
# 0    surge     20
# 1  classes     21
# 2       AI     19
# 3       DS     18
