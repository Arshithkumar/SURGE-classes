# %%
import pandas as pd
data=pd.read_csv('BackOrders_Development.csv')

# %%
data
# Out:
#            sku  national_inv  lead_time  in_transit_qty  forecast_3_month  \
# 0      1682848            11       12.0               0                 0
# 1      1952807             7        4.0               0                 0
# 2      1990960             1        8.0               0                 8
# 3      3250836            36       12.0               1                 5
# 4      3275747            11        8.0               0                 0
# ...        ...           ...        ...             ...               ...
# 60584  1397275             6        8.0               0                24
# 60585  3072139           130        2.0               0                40
# 60586  1909363           135        9.0               0                 0
# 60587  1845783            63        NaN               0                 0
# 60588  1200539             0        2.0               0                 8
#
#        forecast_6_month  forecast_9_month  sales_1_month  sales_3_month  \
# ...

# %%
#Q2) Replace the values of  'went_on_backorder' from’yes’ or ‘no’ to 1 or 0 Use this code: backorder['went_on_backorder'] = backorder['went_on_backorder'].map({'Yes': 1, 'No': 0})
data['went_on_backorder'] = data['went_on_backorder'].map({'Yes': 1, 'No': 0})
data['went_on_backorder']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 60584   NaN
# 60585   NaN
# 60586   NaN
# 60587   NaN
# 60588   NaN
# Name: went_on_backorder, Length: 60589, dtype: float64
