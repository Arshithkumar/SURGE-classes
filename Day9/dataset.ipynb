# %%
import pandas as pd
import numpy as np

data = np.random.rand(5, 3) 
df = pd.DataFrame(data, columns=['Column1', 'Column2', 'Column3'])

print(df)
# Out:
#     Column1   Column2   Column3
# 0  0.902544  0.059241  0.573624
# 1  0.830325  0.137737  0.687574
# 2  0.321159  0.551878  0.008819
# 3  0.089226  0.923541  0.455224
# 4  0.733091  0.417009  0.052589

# %%
import pandas as pd  
  
data = {'col 1': ['Surge', 'classes', 'AI', 'DS'], 'col 2': [20, 21, 19, 18]}  

df = pd.DataFrame(data)  
  
print(df)
# Out:
#      col 1  col 2
# 0    Surge     20
# 1  classes     21
# 2       AI     19
# 3       DS     18
